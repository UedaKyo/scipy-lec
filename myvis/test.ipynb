# %%
# %run test.py
# Out:
# [['day' 'credit' 'etcetra' 'sum' 'buy']
#  ['1' '0' '20' '20' '0']
#  ['2' '400' '5' '405' '0']
#  ['3' '0' '30' '30' '300']]

# %%
# %run test.py

# %%
# %run myvis.py

# %%
# %run myvis.py

# %%
# %run myvis.py

# %%
# %run myvis.py

# %%
# %run newmyvis.py
